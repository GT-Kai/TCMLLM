# %%
import torch
from modelscope import snapshot_download, AutoTokenizer
from transformers import AutoModelForCausalLM, TrainingArguments, Trainer, DataCollatorForSeq2Seq
# 在modelscope上下载Qwen模型到本地目录下
model_dir = snapshot_download("Qwen/Qwen3-8B", cache_dir="./", revision="master")

# Transformers加载模型权重
tokenizer = AutoTokenizer.from_pretrained("./Qwen/Qwen3-8B", use_fast=False, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained("./Qwen/Qwen3-8B", device_map="auto", torch_dtype=torch.bfloat16)
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 8.9
# CUDA SETUP: Detected CUDA version 120
# CUDA SETUP: Loading binary /home/lick/tools/anaconda3/envs/TCMLLM/lib/python3.10/site-packages/bitsandbytes/libbitsandbytes_cuda120.so...
# Downloading Model to directory: ./Qwen/Qwen3-8B
# /home/lick/tools/anaconda3/envs/TCMLLM/lib/python3.10/site-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: /home/lick/tools/anaconda3/envs/TCMLLM did not contain libcudart.so as expected! Searching further paths...
#   warn(msg)
# /home/lick/tools/anaconda3/envs/TCMLLM/lib/python3.10/site-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/home/lick/.cache/dotnet_bundle_extract')}
#   warn(msg)
# /home/lick/tools/anaconda3/envs/TCMLLM/lib/python3.10/site-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('"en","resolvedLanguage"'), PosixPath('"/home/lick/.cursor-server/bin/505046dcfad2acda3d066e32b7cd8b6e2dc1fdc0/out/nls.messages.json","locale"'), PosixPath('{}}'), PosixPath('"en","availableLanguages"'), PosixPath('{"userLocale"'), PosixPath('"en","osLocale"'), PosixPath('"en","defaultMessagesFile"')}
#   warn(msg)
# /home/lick/tools/anaconda3/envs/TCMLLM/lib/python3.10/site-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('vs/workbench/api/node/extensionHostProcess')}
#   warn(msg)
# /home/lick/tools/anaconda3/envs/TCMLLM/lib/python3.10/site-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/home/lick/tools/anaconda3/envs/TCMLLM/etc/xml/catalog file'), PosixPath('file')}
#   warn(msg)
# /home/lick/tools/anaconda3/envs/TCMLLM/lib/python3.10/site-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//matplotlib_inline.backend_inline'), PosixPath('module')}
#   warn(msg)
# 2025-12-01 15:53:59,107 - modelscope - WARNING - Using branch: master as version is unstable, use with caution
# 2025-12-01 15:53:59,370 - modelscope - INFO - Got 15 files, start to download ...
# Processing 15 items:   0%|          | 0/15 [00:00<?, ?it/s]
# Downloading [model-00002-of-00005.safetensors]:   0%|          | 0.00/3.72G [00:00<?, ?B/s]
# Downloading [model-00001-of-00005.safetensors]:   0%|          | 0.00/3.72G [00:00<?, ?B/s]
# Downloading [LICENSE]:   0%|          | 0.00/11.1k [00:00<?, ?B/s]
# Downloading [generation_config.json]:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading [merges.txt]:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# Downloading [config.json]:   0%|          | 0.00/728 [00:00<?, ?B/s]
# Downloading [configuration.json]:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Downloading [model-00003-of-00005.safetensors]:   0%|          | 0.00/3.69G [00:00<?, ?B/s]
# Processing 15 items:   7%|▋         | 1/15 [00:01<00:19,  1.37s/it]
# Downloading [model-00004-of-00005.safetensors]:   0%|          | 0.00/2.97G [00:00<?, ?B/s]
# Downloading [model.safetensors.index.json]:   0%|          | 0.00/32.1k [00:00<?, ?B/s]
# Downloading [model-00005-of-00005.safetensors]:   0%|          | 0.00/1.16G [00:00<?, ?B/s]
# Downloading [README.md]:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# Processing 15 items:  33%|███▎      | 5/15 [00:02<00:04,  2.46it/s]
# Downloading [tokenizer.json]:   0%|          | 0.00/10.9M [00:00<?, ?B/s]
# Processing 15 items:  40%|████      | 6/15 [00:02<00:03,  2.72it/s]
# Downloading [tokenizer_config.json]:   0%|          | 0.00/9.50k [00:00<?, ?B/s]
# Processing 15 items:  47%|████▋     | 7/15 [00:03<00:03,  2.00it/s]
# Downloading [vocab.json]:   0%|          | 0.00/2.65M [00:00<?, ?B/s]
# Processing 15 items:  67%|██████▋   | 10/15 [00:14<00:11,  2.21s/it]
